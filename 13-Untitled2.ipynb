# %% [markdown]
# # Crawl TRIZ Effects Database

# %%
import requests
from itertools import product
from collections import defaultdict
from bs4 import BeautifulSoup

# Type of effect
modes = ['Function', 'Parameter', 'Transform']
base_url = 'http://wbam2244.dns-systems.net//EDB_display_results.php'

def get_mode_items(html):
    def get_items(paramtype):
        css_sel = 'td.{0}_item'.format(paramtype)
        tds = soup.select(css_sel)
        task_item_names = [item.strip() for td in tds for item in td.text.strip().splitlines()]
        task_item_sels = soup.select(css_sel + ' input')
        task_item_values = [int(sel.attrs['value']) for sel in task_item_sels]
        
        return(list(zip(task_item_names, task_item_values)))
    
    soup = BeautifulSoup(html, 'lxml')
    task_items = get_items('task')
    target_items = get_items('target')
    for (taskName, taskValue), (targetName, targetValue) in product(task_items, target_items):
        print(taskName, targetName)
        
    return(task_items, target_items)

res = requests.post('http://wbam2244.dns-systems.net//EDB_select_task_target.php',
                   data = {'mode_button': 'Function'})
task_items, target_items = get_mode_items(res.text)
task_items, target_items
# Out:
# Absorb Divided Solid
# Absorb Field
# Absorb Gas
# Absorb Liquid
# Absorb Solid
# Accumulate Divided Solid
# Accumulate Field
# Accumulate Gas
# Accumulate Liquid
# Accumulate Solid
# Bend Divided Solid
# Bend Field
# Bend Gas
# Bend Liquid
# Bend Solid
# Break Down Divided Solid
# Break Down Field
# Break Down Gas
# Break Down Liquid
# Break Down Solid
# Change Phase Divided Solid
# Change Phase Field
# Change Phase Gas
# Change Phase Liquid
# Change Phase Solid
# Clean Divided Solid
# Clean Field
# Clean Gas
# Clean Liquid
# Clean Solid
# Compress Divided Solid
# Compress Field
# Compress Gas
# Compress Liquid
# Compress Solid
# Concentrate Divided Solid
# Concentrate Field
# Concentrate Gas
# Concentrate Liquid
# Concentrate Solid
# Condense Divided Solid
# Condense Field
# Condense Gas
# Condense Liquid
# Condense Solid
# Constrain Divided Solid
# Constrain Field
# Constrain Gas
# Constrain Liquid
# Constrain Solid
# Cool Divided Solid
# Cool Field
# Cool Gas
# Cool Liquid
# Cool Solid
# Deposit Divided Solid
# Deposit Field
# Deposit Gas
# Deposit Liquid
# Deposit Solid
# Destroy Divided Solid
# Destroy Field
# Destroy Gas
# Destroy Liquid
# Destroy Solid
# Detect Divided Solid
# Detect Field
# Detect Gas
# Detect Liquid
# Detect Solid
# Dilute Divided Solid
# Dilute Field
# Dilute Gas
# Dilute Liquid
# Dilute Solid
# Dry Divided Solid
# Dry Field
# Dry Gas
# Dry Liquid
# Dry Solid
# Evaporate Divided Solid
# Evaporate Field
# Evaporate Gas
# Evaporate Liquid
# Evaporate Solid
# Expand Divided Solid
# Expand Field
# Expand Gas
# Expand Liquid
# Expand Solid
# Extract Divided Solid
# Extract Field
# Extract Gas
# Extract Liquid
# Extract Solid
# Freeze Divided Solid
# Freeze Field
# Freeze Gas
# Freeze Liquid
# Freeze Solid
# Heat Divided Solid
# Heat Field
# Heat Gas
# Heat Liquid
# Heat Solid
# Hold Divided Solid
# Hold Field
# Hold Gas
# Hold Liquid
# Hold Solid
# Join Divided Solid
# Join Field
# Join Gas
# Join Liquid
# Join Solid
# Melt Divided Solid
# Melt Field
# Melt Gas
# Melt Liquid
# Melt Solid
# Mix Divided Solid
# Mix Field
# Mix Gas
# Mix Liquid
# Mix Solid
# Move Divided Solid
# Move Field
# Move Gas
# Move Liquid
# Move Solid
# Orient Divided Solid
# Orient Field
# Orient Gas
# Orient Liquid
# Orient Solid
# Produce Divided Solid
# Produce Field
# Produce Gas
# Produce Liquid
# Produce Solid
# Protect Divided Solid
# Protect Field
# Protect Gas
# Protect Liquid
# Protect Solid
# Purify Divided Solid
# Purify Field
# Purify Gas
# Purify Liquid
# Purify Solid
# Remove Divided Solid
# Remove Field
# Remove Gas
# Remove Liquid
# Remove Solid
# Resist Divided Solid
# Resist Field
# Resist Gas
# Resist Liquid
# Resist Solid
# Rotate Divided Solid
# Rotate Field
# Rotate Gas
# Rotate Liquid
# Rotate Solid
# Separate Divided Solid
# Separate Field
# Separate Gas
# Separate Liquid
# Separate Solid
# Vibrate Divided Solid
# Vibrate Field
# Vibrate Gas
# Vibrate Liquid
# Vibrate Solid
# ([('Absorb', 11),
#   ('Accumulate', 12),
#   ('Bend', 14),
#   ('Break Down', 16),
#   ('Change Phase', 17),
#   ('Clean', 18),
#   ('Compress', 19),
#   ('Concentrate', 20),
#   ('Condense', 21),
#   ('Constrain', 22),
#   ('Cool', 23),
#   ('Deposit', 24),
#   ('Destroy', 25),
#   ('Detect', 26),
#   ('Dilute', 27),
#   ('Dry', 29),
#   ('Evaporate', 30),
#   ('Expand', 31),
#   ('Extract', 32),
#   ('Freeze', 33),
#   ('Heat', 34),
#   ('Hold', 35),
#   ('Join', 36),
#   ('Melt', 37),
#   ('Mix', 38),
#   ('Move', 39),
#   ('Orient', 41),
#   ('Produce', 43),
#   ('Protect', 44),
#   ('Purify', 45),
#   ('Remove', 46),
#   ('Resist', 47),
#   ('Rotate', 48),
#   ('Separate', 49),
#   ('Vibrate', 51)],
#  [('Divided Solid', 3), ('Field', 6), ('Gas', 5), ('Liquid', 4), ('Solid', 2)])

# %%
info = {}
for mode in modes:
    res = requests.post('http://wbam2244.dns-systems.net//EDB_select_task_target.php',
                       data = {'mode_button': mode})
    task_items, target_items = get_mode_items(res.text)
    info[mode] = {
        'task': task_items,
        'target': target_items
    }
info
# Out:
# Absorb Divided Solid
# Absorb Field
# Absorb Gas
# Absorb Liquid
# Absorb Solid
# Accumulate Divided Solid
# Accumulate Field
# Accumulate Gas
# Accumulate Liquid
# Accumulate Solid
# Bend Divided Solid
# Bend Field
# Bend Gas
# Bend Liquid
# Bend Solid
# Break Down Divided Solid
# Break Down Field
# Break Down Gas
# Break Down Liquid
# Break Down Solid
# Change Phase Divided Solid
# Change Phase Field
# Change Phase Gas
# Change Phase Liquid
# Change Phase Solid
# Clean Divided Solid
# Clean Field
# Clean Gas
# Clean Liquid
# Clean Solid
# Compress Divided Solid
# Compress Field
# Compress Gas
# Compress Liquid
# Compress Solid
# Concentrate Divided Solid
# Concentrate Field
# Concentrate Gas
# Concentrate Liquid
# Concentrate Solid
# Condense Divided Solid
# Condense Field
# Condense Gas
# Condense Liquid
# Condense Solid
# Constrain Divided Solid
# Constrain Field
# Constrain Gas
# Constrain Liquid
# Constrain Solid
# Cool Divided Solid
# Cool Field
# Cool Gas
# Cool Liquid
# Cool Solid
# Deposit Divided Solid
# Deposit Field
# Deposit Gas
# Deposit Liquid
# Deposit Solid
# Destroy Divided Solid
# Destroy Field
# Destroy Gas
# Destroy Liquid
# Destroy Solid
# Detect Divided Solid
# Detect Field
# Detect Gas
# Detect Liquid
# Detect Solid
# Dilute Divided Solid
# Dilute Field
# Dilute Gas
# Dilute Liquid
# Dilute Solid
# Dry Divided Solid
# Dry Field
# Dry Gas
# Dry Liquid
# Dry Solid
# Evaporate Divided Solid
# Evaporate Field
# Evaporate Gas
# Evaporate Liquid
# Evaporate Solid
# Expand Divided Solid
# Expand Field
# Expand Gas
# Expand Liquid
# Expand Solid
# Extract Divided Solid
# Extract Field
# Extract Gas
# Extract Liquid
# Extract Solid
# Freeze Divided Solid
# Freeze Field
# Freeze Gas
# Freeze Liquid
# Freeze Solid
# Heat Divided Solid
# Heat Field
# Heat Gas
# Heat Liquid
# Heat Solid
# Hold Divided Solid
# Hold Field
# Hold Gas
# Hold Liquid
# Hold Solid
# Join Divided Solid
# Join Field
# Join Gas
# Join Liquid
# Join Solid
# Melt Divided Solid
# Melt Field
# Melt Gas
# Melt Liquid
# Melt Solid
# Mix Divided Solid
# Mix Field
# Mix Gas
# Mix Liquid
# Mix Solid
# Move Divided Solid
# Move Field
# Move Gas
# Move Liquid
# Move Solid
# Orient Divided Solid
# Orient Field
# Orient Gas
# Orient Liquid
# Orient Solid
# Produce Divided Solid
# Produce Field
# Produce Gas
# Produce Liquid
# Produce Solid
# Protect Divided Solid
# Protect Field
# Protect Gas
# Protect Liquid
# Protect Solid
# Purify Divided Solid
# Purify Field
# Purify Gas
# Purify Liquid
# Purify Solid
# Remove Divided Solid
# Remove Field
# Remove Gas
# Remove Liquid
# Remove Solid
# Resist Divided Solid
# Resist Field
# Resist Gas
# Resist Liquid
# Resist Solid
# Rotate Divided Solid
# Rotate Field
# Rotate Gas
# Rotate Liquid
# Rotate Solid
# Separate Divided Solid
# Separate Field
# Separate Gas
# Separate Liquid
# Separate Solid
# Vibrate Divided Solid
# Vibrate Field
# Vibrate Gas
# Vibrate Liquid
# Vibrate Solid
# Change Brightness
# Change Colour
# Change Concentration
# Change Density
# Change Drag
# Change Electrical Conductivity
# Change Energy
# Change Fluid Flow
# Change Force
# Change Frequency
# Change Friction
# Change Hardness
# Change Heat Conduction
# Change Homogeneity
# Change Humidity
# Change Length
# Change Magnetic Properties
# Change Orientation
# Change Polarisation
# Change Porosity
# Change Position
# Change Power
# Change Pressure
# Change Purity
# Change Rigidity
# Change Shape
# Change Sound
# Change Speed
# Change Strength
# Change Surface Area
# Change Surface Finish
# Change Temperature
# Change Time
# Change Translucency
# Change Viscosity
# Change Volume
# Change Weight
# Decrease Brightness
# Decrease Colour
# Decrease Concentration
# Decrease Density
# Decrease Drag
# Decrease Electrical Conductivity
# Decrease Energy
# Decrease Fluid Flow
# Decrease Force
# Decrease Frequency
# Decrease Friction
# Decrease Hardness
# Decrease Heat Conduction
# Decrease Homogeneity
# Decrease Humidity
# Decrease Length
# Decrease Magnetic Properties
# Decrease Orientation
# Decrease Polarisation
# Decrease Porosity
# Decrease Position
# Decrease Power
# Decrease Pressure
# Decrease Purity
# Decrease Rigidity
# Decrease Shape
# Decrease Sound
# Decrease Speed
# Decrease Strength
# Decrease Surface Area
# Decrease Surface Finish
# Decrease Temperature
# Decrease Time
# Decrease Translucency
# Decrease Viscosity
# Decrease Volume
# Decrease Weight
# Increase Brightness
# Increase Colour
# Increase Concentration
# Increase Density
# Increase Drag
# Increase Electrical Conductivity
# Increase Energy
# Increase Fluid Flow
# Increase Force
# Increase Frequency
# Increase Friction
# Increase Hardness
# Increase Heat Conduction
# Increase Homogeneity
# Increase Humidity
# Increase Length
# Increase Magnetic Properties
# Increase Orientation
# Increase Polarisation
# Increase Porosity
# Increase Position
# Increase Power
# Increase Pressure
# Increase Purity
# Increase Rigidity
# Increase Shape
# Increase Sound
# Increase Speed
# Increase Strength
# Increase Surface Area
# Increase Surface Finish
# Increase Temperature
# Increase Time
# Increase Translucency
# Increase Viscosity
# Increase Volume
# Increase Weight
# Measure Brightness
# Measure Colour
# Measure Concentration
# Measure Density
# Measure Drag
# Measure Electrical Conductivity
# Measure Energy
# Measure Fluid Flow
# Measure Force
# Measure Frequency
# Measure Friction
# Measure Hardness
# Measure Heat Conduction
# Measure Homogeneity
# Measure Humidity
# Measure Length
# Measure Magnetic Properties
# Measure Orientation
# Measure Polarisation
# Measure Porosity
# Measure Position
# Measure Power
# Measure Pressure
# Measure Purity
# Measure Rigidity
# Measure Shape
# Measure Sound
# Measure Speed
# Measure Strength
# Measure Surface Area
# Measure Surface Finish
# Measure Temperature
# Measure Time
# Measure Translucency
# Measure Viscosity
# Measure Volume
# Measure Weight
# Stabilise Brightness
# Stabilise Colour
# Stabilise Concentration
# Stabilise Density
# Stabilise Drag
# Stabilise Electrical Conductivity
# Stabilise Energy
# Stabilise Fluid Flow
# Stabilise Force
# Stabilise Frequency
# Stabilise Friction
# Stabilise Hardness
# Stabilise Heat Conduction
# Stabilise Homogeneity
# Stabilise Humidity
# Stabilise Length
# Stabilise Magnetic Properties
# Stabilise Orientation
# Stabilise Polarisation
# Stabilise Porosity
# Stabilise Position
# Stabilise Power
# Stabilise Pressure
# Stabilise Purity
# Stabilise Rigidity
# Stabilise Shape
# Stabilise Sound
# Stabilise Speed
# Stabilise Strength
# Stabilise Surface Area
# Stabilise Surface Finish
# Stabilise Temperature
# Stabilise Time
# Stabilise Translucency
# Stabilise Viscosity
# Stabilise Volume
# Stabilise Weight
# Acoustic Acoustic
# Acoustic Chemical
# Acoustic Electrical
# Acoustic Electromagnetic
# Acoustic Kinetic
# Acoustic Magnetic
# Acoustic Mechanical
# Acoustic Optical
# Acoustic Thermal
# Chemical Acoustic
# Chemical Chemical
# Chemical Electrical
# Chemical Electromagnetic
# Chemical Kinetic
# Chemical Magnetic
# Chemical Mechanical
# Chemical Optical
# Chemical Thermal
# Electrical Acoustic
# Electrical Chemical
# Electrical Electrical
# Electrical Electromagnetic
# Electrical Kinetic
# Electrical Magnetic
# Electrical Mechanical
# Electrical Optical
# Electrical Thermal
# Electromagnetic Acoustic
# Electromagnetic Chemical
# Electromagnetic Electrical
# Electromagnetic Electromagnetic
# Electromagnetic Kinetic
# Electromagnetic Magnetic
# Electromagnetic Mechanical
# Electromagnetic Optical
# Electromagnetic Thermal
# Kinetic Acoustic
# Kinetic Chemical
# Kinetic Electrical
# Kinetic Electromagnetic
# Kinetic Kinetic
# Kinetic Magnetic
# Kinetic Mechanical
# Kinetic Optical
# Kinetic Thermal
# Magnetic Acoustic
# Magnetic Chemical
# Magnetic Electrical
# Magnetic Electromagnetic
# Magnetic Kinetic
# Magnetic Magnetic
# Magnetic Mechanical
# Magnetic Optical
# Magnetic Thermal
# Mechanical Acoustic
# Mechanical Chemical
# Mechanical Electrical
# Mechanical Electromagnetic
# Mechanical Kinetic
# Mechanical Magnetic
# Mechanical Mechanical
# Mechanical Optical
# Mechanical Thermal
# Optical Acoustic
# Optical Chemical
# Optical Electrical
# Optical Electromagnetic
# Optical Kinetic
# Optical Magnetic
# Optical Mechanical
# Optical Optical
# Optical Thermal
# Thermal Acoustic
# Thermal Chemical
# Thermal Electrical
# Thermal Electromagnetic
# Thermal Kinetic
# Thermal Magnetic
# Thermal Mechanical
# Thermal Optical
# Thermal Thermal
# {'Function': {'target': [('Divided Solid', 3),
#    ('Field', 6),
#    ('Gas', 5),
#    ('Liquid', 4),
#    ('Solid', 2)],
#   'task': [('Absorb', 11),
#    ('Accumulate', 12),
#    ('Bend', 14),
#    ('Break Down', 16),
#    ('Change Phase', 17),
#    ('Clean', 18),
#    ('Compress', 19),
#    ('Concentrate', 20),
#    ('Condense', 21),
#    ('Constrain', 22),
#    ('Cool', 23),
#    ('Deposit', 24),
#    ('Destroy', 25),
#    ('Detect', 26),
#    ('Dilute', 27),
#    ('Dry', 29),
#    ('Evaporate', 30),
#    ('Expand', 31),
#    ('Extract', 32),
#    ('Freeze', 33),
#    ('Heat', 34),
#    ('Hold', 35),
#    ('Join', 36),
#    ('Melt', 37),
#    ('Mix', 38),
#    ('Move', 39),
#    ('Orient', 41),
#    ('Produce', 43),
#    ('Protect', 44),
#    ('Purify', 45),
#    ('Remove', 46),
#    ('Resist', 47),
#    ('Rotate', 48),
#    ('Separate', 49),
#    ('Vibrate', 51)]},
#  'Parameter': {'target': [('Brightness', 7),
#    ('Colour', 8),
#    ('Concentration', 36),
#    ('Density', 9),
#    ('Drag', 10),
#    ('Electrical Conductivity', 11),
#    ('Energy', 12),
#    ('Fluid Flow', 18),
#    ('Force', 13),
#    ('Frequency', 42),
#    ('Friction', 19),
#    ('Hardness', 14),
#    ('Heat Conduction', 15),
#    ('Homogeneity', 16),
#    ('Humidity', 43),
#    ('Length', 17),
#    ('Magnetic Properties', 20),
#    ('Orientation', 39),
#    ('Polarisation', 40),
#    ('Porosity', 21),
#    ('Position', 38),
#    ('Power', 22),
#    ('Pressure', 23),
#    ('Purity', 35),
#    ('Rigidity', 41),
#    ('Shape', 44),
#    ('Sound', 25),
#    ('Speed', 26),
#    ('Strength', 27),
#    ('Surface Area', 28),
#    ('Surface Finish', 29),
#    ('Temperature', 30),
#    ('Time', 37),
#    ('Translucency', 45),
#    ('Viscosity', 32),
#    ('Volume', 33),
#    ('Weight', 34)],
#   'task': [('Change', 52),
#    ('Decrease', 53),
#    ('Increase', 54),
#    ('Measure', 55),
#    ('Stabilise', 56)]},
#  'Transform': {'target': [('Acoustic', 46),
#    ('Chemical', 47),
#    ('Electrical', 48),
#    ('Electromagnetic', 49),
#    ('Kinetic', 50),
#    ('Magnetic', 52),
#    ('Mechanical', 53),
#    ('Optical', 51),
#    ('Thermal', 54)],
#   'task': [('Acoustic', 2),
#    ('Chemical', 3),
#    ('Electrical', 4),
#    ('Electromagnetic', 5),
#    ('Kinetic', 6),
#    ('Magnetic', 8),
#    ('Mechanical', 9),
#    ('Optical', 7),
#    ('Thermal', 10)]}}

# %% [markdown]
# ### Development example

# %%
data = {
    'selected_task': 11,
    'selected_target': 3,
    'filter': 'both',
    'Preserved_Mode_Name': 'Function'
}
res = requests.post(base_url, data = data)

# %%
def get_suggestions(html):
    soup = BeautifulSoup(html, 'lxml')
    table = soup.select('div#main > table')[-1]
    nodes = table.select('td')
    result = [node.text.strip() for node in nodes]
    
    # grouped list items 3 by 3
    suggestions = list(zip(*[iter(result)]*3))
    return(suggestions)

# %% [markdown]
# ### Extract all effects

# %%
effects = defaultdict(dict)
for mode, modeInfo in info.items():
    for task, target in product(modeInfo['task'], modeInfo['target']):
        data['Preserved_Mode_Name'] = mode
        data['selected_task'] = task[1]
        data['selected_target'] = target[1]
        res = requests.post('http://wbam2244.dns-systems.net//EDB_display_results.php',
                           data = data)
        effects[mode][task[0], target[0]] = get_suggestions(res.text)

# %% [markdown]
# ### Dump the result in a json file

# %%
try:
    import ujson as json
except:
    import json

# %%
json.dump(effects, open('13-effects.json', 'w'), ensure_ascii = False,
           indent = 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-663264764ca3> in <module>()
#       1 json.dump(effects, open('13-effects.json', 'w'), ensure_ascii = False,
# ----> 2            indent = 2)
#
# C:\Anaconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# C:\Anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     428             yield from _iterencode_list(o, _current_indent_level)
#     429         elif isinstance(o, dict):
# --> 430             yield from _iterencode_dict(o, _current_indent_level)
#     431         else:
#     432             if markers is not None:
#
# C:\Anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     402                 else:
#     403                     chunks = _iterencode(value, _current_indent_level)
# --> 404                 yield from chunks
#     405         if newline_indent is not None:
#     406             _current_indent_level -= 1
#
# C:\Anaconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     374                 continue
#     375             else:
# --> 376                 raise TypeError("key " + repr(key) + " is not a string")
#     377             if first:
#     378                 first = False
#
# TypeError: key ('Absorb', 'Divided Solid') is not a string

# %%
# !pip3 install ujson
# Out:
# Collecting ujson
#   Using cached ujson-1.35.tar.gz
# Building wheels for collected packages: ujson
#   Running setup.py bdist_wheel for ujson: started
#   Running setup.py bdist_wheel for ujson: finished with status 'done'
#   Stored in directory: C:\Users\Aditya Utama Wijaya\AppData\Local\pip\Cache\wheels\9e\9b\d0\df92653bb5b2664c15d8ee5b99e3f2eb08a034444db8922b2f
# Successfully built ujson
# Installing collected packages: ujson
# Successfully installed ujson-1.35
