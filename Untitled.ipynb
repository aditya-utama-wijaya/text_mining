# %%
import pandas as pd
theses = pd.read_csv('7-theses_final.csv', encoding = 'utf-8')
theses.head(6)
# Out:
#   department            advisor  \
# 0        CTM  CHANG, YUAN CHIEH
# 1        CTM  Chang, Yuan Chieh
# 2        CTM  Chang, Yuan-Chieh
# 3        CTM   Chang,Yuan Chieh
# 4        CTM     Chen, Pao Lien
# 5        CTM     Chen, Pao-Lien
#
#                                             abstract  \
# 0  R&D internationalization of the multinational ...
# 1  This study focuses on the development of unive...
# 2  The concept of entrepreneurial university, con...
# 3  Innovation taxonomy offers a comprehensive way...
# 4  In retrospect the history of Taiwan industry d...
# 5       Because of the interest in social enterpr...
#
#                                   abstract_tokenized
# 0  ['r', 'internationalization', 'multinational',...
# 1  ['study', 'focuses', 'development', 'universit...
# 2  ['concept', 'entrepreneurial', 'university', '...
# 3  ['innovation', 'taxonomy', 'offers', 'comprehe...
# 4  ['retrospect', 'history', 'taiwan', 'industry'...
# ...

# %%
import pandas as pd
theses_imba = pd.read_csv('theses_IMBA.csv', encoding = 'utf-8')
theses_imba.ix[:, (0, 1, 3)]
# Out:
#    department                 advisor  \
# 0        IMBA       Chang, Yuan-Chieh
# 1        IMBA        Chiu, Hung-Chang
# 2        IMBA        Chiu, Hung Chang
# 3        IMBA           Galit Shmueli
# 4        IMBA        Hsieh,  Ying-Che
# 5        IMBA     Hsieh, ALI Ying-Che
# 6        IMBA         Hsieh, Ying-Che
# 7        IMBA         Hsieh, Ying Che
# 8        IMBA          Hsieh,Ying-Che
# 9        IMBA           Lin, Che-chun
# 10       IMBA           Lin, Che-Chun
# 11       IMBA           Lin, Che Chun
# 12       IMBA          Lu, Shu Shuian
# 13       IMBA             Ray, Soumya
# 14       IMBA              Soumya Ray
# 15       IMBA  Stephen Jui-Hsien Chou
# 16       IMBA           Wang, Chen-Ya
# 17       IMBA           Wang, Chen Ya
# 18       IMBA        Wang, Jyun-Cheng
#
#                                    abstract_tokenized
# 0                               ['因申請專利緣故', '資料延後公開']
# 1   ['prevalence', 'high', 'technology', 'globali'...
# ...
